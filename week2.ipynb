# %% [markdown]
# <a href="https://colab.research.google.com/github/nazzaladiy/PCVK_Genap_2022/blob/master/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
path = '/content/drive/MyDrive/PCVK_MM/Images/kitten01.jfif'
img = cv.imread (path)
plt.imshow(img)                           #perhatikan hasilnya adalah citra dgn channel warna BGR
plt.show()

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jfif' , cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan File image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2/tiff,img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))     #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype = np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))  # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **PERTANYAAN**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# - Jawab : Matplotlib adalah library Python yang fokus pada visualisasi data seperti membuat plot grafik.Visualisasi dari matplotlib adalah sebuah gambar grafik yang terdapat satu sumbu atau lebih. Setiap sumbu memiliki sumbu horizontal (x) dan sumbu vertikal (y), dan data yang direpresentasikan menjadi warna dan glyphs seperti marker (contohnya bentuk lingkaran) atau lines (garis) atau poligon. Maka dari itu jika tanpa menggunakan metplotlib tidak muncul plot grafifk.
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# - Jawab : Perbedaannya terletak pada hasil ukuran file image yang dihasilkan. Antara pembuatan black image tipe data int16 dengan int32, maka hasil ukuran file image yang dihasilkan lebih besar int32. Hal tersebut dapat mempengaruhi tingkat intensitas dari suatu image tersebut
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# - Jawab : Numpy memungkinkan kita untuk memberikan salah satu parameter bentuk baru sebagai -1 (misalnya: (2,-1) atau (-1,3) tetapi tidak (-1, -1)). Ini berarti bahwa itu adalah dimensi yang tidak diketahui. Untuk nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, B
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# - Jawab : import adalah fungsi Python untuk memanggil modul di luar fungsi dasar yang disediakan, cv2 adalah nama modul Python yang digunakan untuk memanggil fungsi-fungsi OpenCV, cv2_imshow perintah yang digunakan pada modul cv2 untuk menampilkan citra. Argumen yang diperlukan adalah nama citra yang dipanggil
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
# - Jawab : Saat diimpor, skimage menyimpan informasi untuk setiap piksel dalam array NumPy n-dimensi. Bentuk persegi panjang dari array sesuai dengan bentuk gambar, meskipun urutan koordinatnya terbalik.

# %% [markdown]
# **TUGAS**

# %%
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %%
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
black_img = np.zeros(shape=(512,512,3), dtype = np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(100,100), pt2=(260,260), color=(255,0,0), thickness=6)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(150,200), pt2=(100,100), color=(255,0,255), thickness=9)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(150,200), pt2=(250,100), color=(255,0,255), thickness=13)
plt.imshow(black_img)

# %%
# 5. Tampilkan image dengan posisi terbalik!
fig = plt.figure(figsize=(5,5))     #ubah-ubah ukuran (5,5) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!
img_f = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jfif')
plt.imshow(img_f)

cv.circle(img_f, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(img_f)

# %%
cv.rectangle(img_f, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(img_f)

# %%
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
img_g = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jfif')
plt.imshow(img_g)

# %%
img_rgb = cv.cvtColor(img_g,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
cv.rectangle(img_rgb,pt1=(100,600),pt2=(10,500),color=(0,255,0),thickness=10)
plt.imshow(img_rgb)
